# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg" width="350px" height="180px" />
#
#
# # <font color= #8A0829> Laboratorio de Modelado de Datos </font>
# #### <font color= #2E9AFE> `Martes y Viernes (Videoconferencia) de 13:00 - 15:00 hrs`</font>
# - <Strong> Sara Eugenia Rodríguez </Strong>
# - <Strong> Año </Strong>: 2025
# - <Strong> Email: </Strong>  <font color="blue"> `cd682324@iteso.mx` </font>
# ___
#
# <p style="text-align:right;"> Imagen recuperada de: https://bernardmarr.com/img/What%20is%20an%20Artificial%20Neural%20Networks.jpg</p>
#
# ### <font color= #2E9AFE> Tema: Redes Neuronales</font>

# %% [markdown]
# Las redes neuronales profundas (deep learning) han ganado mucha popularidad en los últimos años, especialmente para problemas complejos, como el reconocimiento de imágenes, el procesamiento del lenguaje natural y otras aplicaciones que requieren modelos potentes.
#
# Sin embargo, las redes neuronales básicas también pueden usarse en problemas de aprendizaje supervisado más simples, como regresión o clasificación, AUNQUE hay varias razones por las cuales otros algoritmos son más comunes en estos casos...
#
# 1. Complejidad computacional
# 2. Sobreajuste (Overfitting)
# 3. Necesidad de más datos
# 4. Tuning de Hiperparámetros (las redes neuronales tienen muchos hiperparámetros)
# 5. Interpretabilidad, son modelos de caja negra
#
# **¿Cuándo se utilizan redes neuronales en aprendizaje supervisado?**
#
# Aunque no siempre son la primera opción para problemas simples, las redes neuronales pueden ser muy útiles en problemas supervisados más complejos donde:
#
# - Hay gran cantidad de datos disponibles
# - Los problemas son no lineales
# - Hay tareas de percepción involucradas (como visión por computadora, reconocimiento de voz o procesamiento de lenguaje natural), donde las redes neuronales profundas sobresalen.

# %% [markdown]
# Dentro de la caja negra...
#
# **¿Qué es una neurona?**
#
# Es un nombre elegante que le pusieron para referirse a una función en los años de 1940-1950. Se creeía que los nodos eran como neuronas del cerebro.
#
# **¿Qué es una función?**
#
# Es un nombre elegante que pusieron para referirse a algo que toma cosas de entrada, aplica alguna lógica y saca un resultado.
#
# **¿Qué es una red neuronal?**
#
# Es la interconexión de múltiples neuronas (funciones) para resolver un problema complejo que una sola neurona no podría. Dentro de los componentes existen *nodos* y *conexiones*
#
# **Pasos que hace la red neuronal:**
#
# 1. Combinación de las variables de entrada (X). Cada señal recibida tiene una constante w (peso/weight) que permite manipular la importancia de cada variable de entrada.
# 2. Neurona de respuesta. Considerando todas las variables de entrada, la neurona genera una señal de respuesta a través de una función.
#
# **Tipos de capas en la red neuronal**
#
# - Capa de entrada: capa que toma los datos de entrada
# - Capas ocultas: toman las entradas de otra capa y pasan a salida hacia otra capa (son intermediarias entre la entrada y la salida)
# - Capas de salida: capa que hace la predicción
#
# <img style="float: center; margin: 0px 0px 0px 0px;" src="https://www.smartsheet.com/sites/default/files/IC-simplified-artificial-neural-networks-corrected.svg" width="350px" height="180px" />

# %% [markdown]
# **Funciones de activación**
#
# El comportamiento de las neuronas de las redes neuronales es basado en la función en la que la neurona se especializó. Una neurona puede cambiar su respuesta dependiendo de la función de activación $\varphi(*)$ que sea seleccionada
#
# Funciones comunes:
# 1. Lineal: $\varphi(\nu)=\nu$
# 2. Sigmoidal: $\varphi(\nu)=\frac{e^{\nu}}{1+e^{\nu}}$
# 3. Tanh: $\varphi(\nu)=\frac{e^{\nu}-e^{-\nu}}{e^{\nu}+e^{-\nu}}=tanh(\nu)$
# 4. Softplus: $\varphi(\nu)=log(1+e^{\nu})$
# 5. RELU: $\varphi(\nu)=max(0,\nu)$
#
# Las funciones de activación suelen ser diferenciables, lo que significa que la derivada de primer orden se puede calcular para un valor de entrada dado. Esto es necesario dado que las redes neuronales generalmente se entrenan utilizando el algoritmo de backpropagation que requiere la derivada del error de predicción para actualizar los pesos del modelo.
#
# **¿Cómo elegir la función de activación para las capas ocultas?**
#
# - RELU: es la más utilizada para capas ocultas. Es fácil de calcular, lo que la hace más rápida para entrenar. Es simple de implementar y no es tan susceptible a gradientes que se desvanecen
# - Leaky RELU: Similar a ReLU, pero permite valores negativos pequeños cuando x≤0, lo que evita que las neuronas queden completamente inactivas.
# - Evita Sigmoid y Tanh en las capas ocultas
#
# **¿Cómo elegir la función de activación para las capas de salida?**
#
# - Lineal: Para problemas de regresión donde la salida es un valor continuo.
# - Sigmoidal: típicamente para problemas de clasificación binaria.
# - Softmax: Para problemas de clasificación multiclase
#
#
# **¿Cómo son las redes neuronales para regresión?**
#
# $$\nu^{1} = w_{0}^{1}+w^{1}$$
# $$y^{1} = \varphi(\nu^{1})$$
# $$\nu^{2} = w_{0}^{2}+w^{2}y_{1}$$
# <font color= #2E9AFE>$$y^{2} = \varphi(\nu^{2})$$</font>
#
# La única diferencia es la última salida. La función de la salida tiene que ser **lineal**
#
#
# **¿Cómo elegir cuántas capas ocultas?**
#
# - Problemas sencillos: Una sola capa oculta suele ser suficiente para capturar patrones simples.
# - Problemas más complejos (con relaciones no lineales más complicadas): Dos capas ocultas pueden ser útiles
#
# En la práctica, la mayoría de los problemas sencillos no necesitan más de 1 o 2 capas ocultas.
#
# **¿Cómo elegir cuántas neuronas en las capas ocultas?**
#
# - Un buen punto de partida es comenzar con un número de neuronas que sea similar o cercano al número de características de entrada.
# - Para problemas simples, puedes comenzar con entre 4 y 16 neuronas por capa.
# - Si los datos tienen una cantidad moderada de complejidad o son no lineales, podrías aumentar a 32 o 64 neuronas en la capa oculta.
# - Evita tener muchas más neuronas que características de entrada, ya que eso puede llevar a un sobreajuste.
# - En redes con múltiples capas ocultas, una estrategia común es que las capas posteriores tengan menos neuronas que las capas iniciales. Esto es porque las primeras capas extraen más características, mientras que las capas más profundas se enfocan en combinarlas.
#
# **Recomendaciones**
#
# - Se recomienda hacer un pre-procesamiento de los datos - Escalamiento
# - Comúnmente todas las capas ocultas usan la misma función de activación
# - La función de salida generalmente usa diferente función de activación que el de las capas ocultas.
# - En la experiencia, conviene más aumentar el número de neuronas ocultas en lugar de aumentar el número de capas ocultas.
# - Se recomienda no usar muchas capas ocultas
#
#
# **¿Por qué el deep learning no funciona tan bien en problemas clásicos de regresión/clasificación?**
#
# Gran parte del éxito de las redes neuronales modernas proviene de su capacidad para explotar la naturaleza compositiva del mundo. Es decir, en problemas de percepción como el análisis de imágenes o audio, las características tienen un orden (espacial o temporal) y los patrones locales se agregan para formar conceptos y objetos de nivel superior (por ejemplo, la imagen de un automóvil está hecha de ruedas y otras partes, que están hechas de características visuales de nivel inferior, que están hechas de formas básicas como bordes, círculos y líneas, etc.).
#
# Las redes neuronales modernas, como las redes neuronales convolucionales (CNN), aprovechan esto aprendiendo características cada vez más abstractas en las capas más profundas.
#
# Por el contrario, los problemas de regresión clásicos constan de una serie de características no ordenadas, y el valor objetivo se puede predecir bastante bien con un modelo lineal/no lineal superficial de las características de entrada. En cierto sentido, esta propiedad composicional presente en problemas como la clasificación de imágenes o el reconocimiento de voz no está presente en problemas como "Predecir los ingresos de un individuo en función de su sexo, edad, nacionalidad, grado académico, tamaño de la familia...".

# %% [markdown]
# ## Ejemplo: Eficiencia de Energia
#
# Se busca analizar la eficiencia energética de los edificios.
#
# Se realizaron análisis energéticos utilizando 12 tipos de edificios diferentes simulados en Ecotect.
#
# Los edificios se diferencian en cuanto a la superficie con cristales, la distribución del área acristalada y la orientación, entre otros parámetros.
#
# Se simularon varios escenarios en función de las características antes mencionadas para obtener 768 formas de edificios.
#
# El conjunto de datos comprende 768 muestras y 8 características, con el objetivo de predecir dos respuestas con valor real.
#
# Información de atributos:
# - X1 Relative Compactness
# - X2 Surface Area
# - X3 Wall Area
# - X4 Roof Area
# - X5 Overall Height
# - X6 Orientation
# - X7 Glazing Area
# - X8 Glazing Area Distribution
#
# Targets:
# - Y1: Heating Load (in Wh)
# - Y2: Cooling Load (in Wh)
# -
# Las características son numéricas y representan diversas características físicas del edificio, mientras que las variables objetivo representan la energía necesaria para calefacción y enfriamiento.

# %%
# pip install tensorflow

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ENB2012_data.csv")

df.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# 25%      0.100000    1.75000   12.992500   15.620000
# 50%      0.250000    3.00000   18.950000   22.080000
# 75%      0.400000    4.00000   31.667500   33.132500
# max      0.400000    5.00000   43.100000   48.030000

# %%
#Matriz de correlaciones
correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %%
#Correlaciones con el target
correlation_target = df.corr()[['Y1','Y2']]
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_target, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Target')
plt.show()

# %%
#Distribucion de las varialbes
sns.pairplot(df)

# %% [markdown]
# ### Modelado

# %% [markdown]
# Vamos a usar una red compartida con dos salidas (cooling and heating load), ya que los dos targets están físicamente relacionados y la red puede aprender representaciones compartidas.
#
# Algunos tips para empezar la arquitectura inicial de la red:
#
# **a. Entrada y salida**
#
# - Entradas: 8 características → tamaño de capa de entrada = 8
# - Salidas: 2 objetivos → tamaño de capa de salida = 2
#
# **b. Capas ocultas**
#
# Por lo general, comienzas poco a poco y vas ampliando:
#
# - Comienza con 1 a 2 capas ocultas.
# - Numero de neuronas: entre el tamaño de entrada y salida (8) y tal vez entre 2 y 4 veces más (16–32–64).
#
# Por ejemplo:
# Input (8)
# ↓
# Dense(64, ReLU)
# ↓
# Dense(32, ReLU)
# ↓
# Dense(2, Linear)
#
# **c. Funcion de activacion**
#
# Comenzar con RELU para capas ocultas
#
# **d. Agregar Regularizacion**
#
# Agregar regularizacion si vemos overfitting (dropout)
#
# **e. Funcion de costo**
#
# MSE
#
# **f. Optimizer**
#
# Adam

# %%
X = df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8']].values
y1 = df['Y1'].values  # Heating Load
y2 = df['Y2'].values  # Cooling Load

# %%
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size=0.2, random_state=42)

# %%
# Estandarizamos los datos
scaler=StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Modelo Baseline

# %%
# Capa de entrada (8 variables)
input_layer = Input(shape=(X_train.shape[1],), name='input_layer')

# Capas ocultas compartidas
layer_dense1_shared=Dense(64 , activation='relu', name='shared_dense_1')(input_layer)
layer_dense2_shared=Dense(32,activation='relu',name='shared_dense_2')(layer_dense1_shared)
layer_dropout1_shared=Dropout(0.2,name='shared_dropout_1')(layer_dense2_shared)

#Estructura para Y1 (Heating Load)
y1_dense_1=Dense(32, activation='relu',name='y1_dense_1')(layer_dropout1_shared)
y1_dropout = Dropout(0.2, name='y1_dropout')(y1_dense_1)
y1_dense2 = Dense(16, activation='relu', name='y1_dense_2')(y1_dropout)
y1_output = Dense(1, name='y1_output')(y1_dense2)

#Estructura para Y2 (Cooling Load)
y2_dense1 = Dense(32, activation='relu', name='y2_dense_1')(layer_dropout1_shared)
y2_dropout = Dropout(0.2, name='y2_dropout')(y2_dense1)
y2_dense3 = Dense(16, activation='relu', name='y2_dense_3')(y2_dropout)
y2_output = Dense(1, name='y2_output')(y2_dense3)

# %%
#  Modelo que contenga la capa de entrada y las capas de salida 
model=Model(inputs=input_layer  ,outputs=[y1_output , y2_output])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 8)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_1      │ (None, 64)        │        576 │ input_layer[0][0] │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dense_2      │ (None, 32)        │      2,080 │ shared_dense_1[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared_dropout_1    │ (None, 32)        │          0 │ shared_dense_2[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_1 (Dense)  │ (None, 32)        │      1,056 │ shared_dropout_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dropout          │ (None, 32)        │          0 │ y1_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dropout          │ (None, 32)        │          0 │ y2_dense_1[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_dense_2 (Dense)  │ (None, 16)        │        528 │ y1_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_dense_3 (Dense)  │ (None, 16)        │        528 │ y2_dropout[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y1_output (Dense)   │ (None, 1)         │         17 │ y1_dense_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ y2_output (Dense)   │ (None, 1)         │         17 │ y2_dense_3[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,858 (22.88 KB)
#  Trainable params: 5,858 (22.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilamos el modelo

model.compile(optimizer='adam', 
              loss={'y1_output': 'mse', 'y2_output': 'mse'}, 
              metrics={'y1_output': 'mae', 'y2_output': 'mae'})

# Entrenamos el modelo
history = model.fit(X_train, [y1_train, y2_train], epochs=200, batch_size=32, 
                    validation_data=(X_test, [y1_test, y2_test]))
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1273.4664 - y1_output_loss: 573.9196 - y1_output_mae: 21.6597 - y2_output_loss: 699.3187 - y2_output_mae: 24.5844 - val_loss: 1249.1980 - val_y1_output_loss: 546.6423 - val_y1_output_mae: 20.9608 - val_y2_output_loss: 712.5787 - val_y2_output_mae: 24.7622
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1092.0005 - y1_output_loss: 452.7813 - y1_output_mae: 18.9656 - y2_output_loss: 635.8843 - y2_output_mae: 23.4455 - val_loss: 945.1510 - val_y1_output_loss: 325.6498 - val_y1_output_mae: 15.2417 - val_y2_output_loss: 627.6056 - val_y2_output_mae: 22.9606
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 765.1219 - y1_output_loss: 230.0218 - y1_output_mae: 12.0197 - y2_output_loss: 534.4385 - y2_output_mae: 21.0189 - val_loss: 432.3946 - val_y1_output_loss: 63.3447 - val_y1_output_mae: 6.3921 - val_y2_output_loss: 372.8232 - val_y2_output_mae: 16.9672
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 335.6628 - y1_output_loss: 77.6473 - y1_output_mae: 6.9438 - y2_output_loss: 257.7385 - y2_output_mae: 13.4027 - val_loss: 109.9458 - val_y1_output_loss: 43.4698 - val_y1_output_mae: 4.3770 - val_y2_output_loss: 67.3868 - val_y2_output_mae: 6.1259
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 121.4505 - y1_output_loss: 52.1567 - y1_output_mae: 5.1323 - y2_output_loss: 69.7661 - y2_output_mae: 6.1729 - val_loss: 82.7995 - val_y1_output_loss: 42.7167 - val_y1_output_mae: 4.9898 - val_y2_output_loss: 40.4487 - val_y2_output_mae: 4.7789
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 106.3650 - y1_output_loss: 51.3731 - y1_output_mae: 5.2806 - y2_output_loss: 54.6780 - y2_output_mae: 5.6471 - val_loss: 71.3426 - val_y1_output_loss: 30.6195 - val_y1_output_mae: 3.9926 - val_y2_output_loss: 40.9894 - val_y2_output_mae: 4.6896
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 95.7746 - y1_output_loss: 44.1371 - y1_output_mae: 4.9160 - y2_output_loss: 51.4033 - y2_output_mae: 5.3860 - val_loss: 60.9795 - val_y1_output_loss: 27.6348 - val_y1_output_mae: 3.7257 - val_y2_output_loss: 33.4412 - val_y2_output_mae: 4.3561
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 92.6125 - y1_output_loss: 42.3329 - y1_output_mae: 4.5923 - y2_output_loss: 50.3518 - y2_output_mae: 5.1199 - val_loss: 57.1530 - val_y1_output_loss: 26.2621 - val_y1_output_mae: 3.5121 - val_y2_output_loss: 31.0620 - val_y2_output_mae: 4.0616
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 80.8887 - y1_output_loss: 39.4348 - y1_output_mae: 4.5691 - y2_output_loss: 41.3971 - y2_output_mae: 4.9253 - val_loss: 53.3322 - val_y1_output_loss: 23.6070 - val_y1_output_mae: 3.3148 - val_y2_output_loss: 29.9540 - val_y2_output_mae: 3.8471
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 71.6919 - y1_output_loss: 32.5500 - y1_output_mae: 4.2788 - y2_output_loss: 39.0372 - y2_output_mae: 4.6919 - val_loss: 48.6117 - val_y1_output_loss: 22.1524 - val_y1_output_mae: 3.2269 - val_y2_output_loss: 26.7094 - val_y2_output_mae: 3.7040
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 71.6888 - y1_output_loss: 32.3263 - y1_output_mae: 4.3474 - y2_output_loss: 39.2901 - y2_output_mae: 4.7666 - val_loss: 43.7772 - val_y1_output_loss: 19.7668 - val_y1_output_mae: 3.1964 - val_y2_output_loss: 24.2375 - val_y2_output_mae: 3.5495
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 78.6808 - y1_output_loss: 35.6116 - y1_output_mae: 4.4627 - y2_output_loss: 43.0009 - y2_output_mae: 4.8215 - val_loss: 42.4202 - val_y1_output_loss: 19.9901 - val_y1_output_mae: 2.9972 - val_y2_output_loss: 22.6620 - val_y2_output_mae: 3.3399
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 72.2133 - y1_output_loss: 33.7965 - y1_output_mae: 4.3400 - y2_output_loss: 38.2997 - y2_output_mae: 4.5722 - val_loss: 39.5482 - val_y1_output_loss: 17.6384 - val_y1_output_mae: 2.8466 - val_y2_output_loss: 22.0875 - val_y2_output_mae: 3.2207
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 67.1250 - y1_output_loss: 28.9402 - y1_output_mae: 3.9070 - y2_output_loss: 38.5596 - y2_output_mae: 4.6102 - val_loss: 35.6332 - val_y1_output_loss: 16.1058 - val_y1_output_mae: 2.7627 - val_y2_output_loss: 19.6375 - val_y2_output_mae: 3.1250
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.0506 - y1_output_loss: 28.9375 - y1_output_mae: 3.8905 - y2_output_loss: 32.3493 - y2_output_mae: 4.1861 - val_loss: 35.7637 - val_y1_output_loss: 17.0011 - val_y1_output_mae: 2.7469 - val_y2_output_loss: 18.9163 - val_y2_output_mae: 3.0224
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56.6750 - y1_output_loss: 27.4709 - y1_output_mae: 3.8849 - y2_output_loss: 29.3478 - y2_output_mae: 4.1765 - val_loss: 31.3613 - val_y1_output_loss: 14.1414 - val_y1_output_mae: 2.5965 - val_y2_output_loss: 17.3873 - val_y2_output_mae: 2.9357
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.2777 - y1_output_loss: 24.3670 - y1_output_mae: 3.6540 - y2_output_loss: 29.1442 - y2_output_mae: 3.9460 - val_loss: 32.7145 - val_y1_output_loss: 15.0310 - val_y1_output_mae: 2.6517 - val_y2_output_loss: 17.9641 - val_y2_output_mae: 2.8554
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 53.4453 - y1_output_loss: 24.1878 - y1_output_mae: 3.6409 - y2_output_loss: 29.1710 - y2_output_mae: 4.0341 - val_loss: 28.9479 - val_y1_output_loss: 12.9927 - val_y1_output_mae: 2.4662 - val_y2_output_loss: 16.0768 - val_y2_output_mae: 2.7681
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58.6161 - y1_output_loss: 25.5241 - y1_output_mae: 3.8497 - y2_output_loss: 33.1344 - y2_output_mae: 4.2209 - val_loss: 26.0128 - val_y1_output_loss: 11.8119 - val_y1_output_mae: 2.5280 - val_y2_output_loss: 14.1474 - val_y2_output_mae: 2.7611
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.6590 - y1_output_loss: 23.3323 - y1_output_mae: 3.5747 - y2_output_loss: 27.3243 - y2_output_mae: 3.9877 - val_loss: 26.2676 - val_y1_output_loss: 11.6019 - val_y1_output_mae: 2.3604 - val_y2_output_loss: 14.6813 - val_y2_output_mae: 2.6498
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.4784 - y1_output_loss: 21.8858 - y1_output_mae: 3.3179 - y2_output_loss: 28.5519 - y2_output_mae: 3.9635 - val_loss: 25.1165 - val_y1_output_loss: 11.8336 - val_y1_output_mae: 2.3656 - val_y2_output_loss: 13.2971 - val_y2_output_mae: 2.4810
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.6833 - y1_output_loss: 22.5554 - y1_output_mae: 3.6153 - y2_output_loss: 28.0162 - y2_output_mae: 3.9271 - val_loss: 25.9237 - val_y1_output_loss: 11.3865 - val_y1_output_mae: 2.3209 - val_y2_output_loss: 14.5837 - val_y2_output_mae: 2.5733
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.3608 - y1_output_loss: 20.0409 - y1_output_mae: 3.3504 - y2_output_loss: 24.3093 - y2_output_mae: 3.7202 - val_loss: 23.3273 - val_y1_output_loss: 10.8713 - val_y1_output_mae: 2.2781 - val_y2_output_loss: 12.4510 - val_y2_output_mae: 2.4611
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.5671 - y1_output_loss: 18.4899 - y1_output_mae: 3.1641 - y2_output_loss: 24.9384 - y2_output_mae: 3.7738 - val_loss: 22.3039 - val_y1_output_loss: 10.0065 - val_y1_output_mae: 2.2433 - val_y2_output_loss: 12.2989 - val_y2_output_mae: 2.4854
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.2129 - y1_output_loss: 21.2323 - y1_output_mae: 3.4521 - y2_output_loss: 22.9546 - y2_output_mae: 3.7000 - val_loss: 20.9557 - val_y1_output_loss: 9.5421 - val_y1_output_mae: 2.1880 - val_y2_output_loss: 11.3843 - val_y2_output_mae: 2.3613
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 39.9727 - y1_output_loss: 20.3715 - y1_output_mae: 3.3065 - y2_output_loss: 19.5939 - y2_output_mae: 3.2956 - val_loss: 22.5910 - val_y1_output_loss: 10.4072 - val_y1_output_mae: 2.3078 - val_y2_output_loss: 12.2590 - val_y2_output_mae: 2.4186
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.6236 - y1_output_loss: 20.5619 - y1_output_mae: 3.2605 - y2_output_loss: 23.0446 - y2_output_mae: 3.5731 - val_loss: 24.6231 - val_y1_output_loss: 10.2832 - val_y1_output_mae: 2.2675 - val_y2_output_loss: 14.4495 - val_y2_output_mae: 2.6400
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.7443 - y1_output_loss: 21.0399 - y1_output_mae: 3.3911 - y2_output_loss: 21.5688 - y2_output_mae: 3.3550 - val_loss: 21.6811 - val_y1_output_loss: 10.0991 - val_y1_output_mae: 2.2170 - val_y2_output_loss: 11.5693 - val_y2_output_mae: 2.3776
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 43.9896 - y1_output_loss: 22.1073 - y1_output_mae: 3.5376 - y2_output_loss: 21.7728 - y2_output_mae: 3.6475 - val_loss: 20.5105 - val_y1_output_loss: 8.9517 - val_y1_output_mae: 2.1278 - val_y2_output_loss: 11.5074 - val_y2_output_mae: 2.2894
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.3853 - y1_output_loss: 22.6214 - y1_output_mae: 3.4007 - y2_output_loss: 23.7812 - y2_output_mae: 3.5582 - val_loss: 21.7828 - val_y1_output_loss: 10.0205 - val_y1_output_mae: 2.2237 - val_y2_output_loss: 11.7786 - val_y2_output_mae: 2.2986
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 42.8702 - y1_output_loss: 20.5296 - y1_output_mae: 3.3157 - y2_output_loss: 22.2046 - y2_output_mae: 3.6282 - val_loss: 19.1137 - val_y1_output_loss: 8.8097 - val_y1_output_mae: 2.0341 - val_y2_output_loss: 10.2457 - val_y2_output_mae: 2.2214
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.5831 - y1_output_loss: 18.9621 - y1_output_mae: 3.2596 - y2_output_loss: 25.7447 - y2_output_mae: 3.6728 - val_loss: 20.5814 - val_y1_output_loss: 9.4896 - val_y1_output_mae: 2.2106 - val_y2_output_loss: 11.0895 - val_y2_output_mae: 2.2506
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.1213 - y1_output_loss: 21.9216 - y1_output_mae: 3.4654 - y2_output_loss: 26.2134 - y2_output_mae: 3.8123 - val_loss: 22.1317 - val_y1_output_loss: 9.3038 - val_y1_output_mae: 2.2415 - val_y2_output_loss: 12.9089 - val_y2_output_mae: 2.5395
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 44.6254 - y1_output_loss: 20.0237 - y1_output_mae: 3.3400 - y2_output_loss: 24.4893 - y2_output_mae: 3.7733 - val_loss: 18.5361 - val_y1_output_loss: 8.1340 - val_y1_output_mae: 2.0086 - val_y2_output_loss: 10.3903 - val_y2_output_mae: 2.1773
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.5310 - y1_output_loss: 16.7589 - y1_output_mae: 3.1775 - y2_output_loss: 23.6974 - y2_output_mae: 3.6504 - val_loss: 17.8344 - val_y1_output_loss: 8.1002 - val_y1_output_mae: 2.0584 - val_y2_output_loss: 9.7095 - val_y2_output_mae: 2.1609
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.9901 - y1_output_loss: 18.4163 - y1_output_mae: 3.1656 - y2_output_loss: 20.6277 - y2_output_mae: 3.4576 - val_loss: 19.3189 - val_y1_output_loss: 8.9671 - val_y1_output_mae: 2.1523 - val_y2_output_loss: 10.3714 - val_y2_output_mae: 2.1860
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.1737 - y1_output_loss: 19.7556 - y1_output_mae: 3.3001 - y2_output_loss: 20.4530 - y2_output_mae: 3.4467 - val_loss: 20.9499 - val_y1_output_loss: 8.4554 - val_y1_output_mae: 2.1350 - val_y2_output_loss: 12.5924 - val_y2_output_mae: 2.4606
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.3120 - y1_output_loss: 16.4471 - y1_output_mae: 3.0833 - y2_output_loss: 19.8625 - y2_output_mae: 3.4054 - val_loss: 23.6425 - val_y1_output_loss: 12.1027 - val_y1_output_mae: 2.7486 - val_y2_output_loss: 11.6267 - val_y2_output_mae: 2.4069
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.8818 - y1_output_loss: 15.9872 - y1_output_mae: 2.9997 - y2_output_loss: 18.8940 - y2_output_mae: 3.2446 - val_loss: 25.7869 - val_y1_output_loss: 12.8917 - val_y1_output_mae: 2.7720 - val_y2_output_loss: 13.0538 - val_y2_output_mae: 2.5360
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.5238 - y1_output_loss: 17.8624 - y1_output_mae: 3.1482 - y2_output_loss: 23.5736 - y2_output_mae: 3.6279 - val_loss: 23.5719 - val_y1_output_loss: 10.6750 - val_y1_output_mae: 2.5581 - val_y2_output_loss: 13.0468 - val_y2_output_mae: 2.5978
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 40.2879 - y1_output_loss: 17.7017 - y1_output_mae: 2.9528 - y2_output_loss: 22.5405 - y2_output_mae: 3.5045 - val_loss: 22.1662 - val_y1_output_loss: 11.1776 - val_y1_output_mae: 2.6385 - val_y2_output_loss: 11.1037 - val_y2_output_mae: 2.3544
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.2592 - y1_output_loss: 16.1492 - y1_output_mae: 3.0297 - y2_output_loss: 21.0452 - y2_output_mae: 3.4405 - val_loss: 18.7582 - val_y1_output_loss: 8.4571 - val_y1_output_mae: 2.1690 - val_y2_output_loss: 10.3406 - val_y2_output_mae: 2.2043
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 38.4336 - y1_output_loss: 17.6542 - y1_output_mae: 3.0989 - y2_output_loss: 20.7982 - y2_output_mae: 3.3989 - val_loss: 25.3051 - val_y1_output_loss: 11.5565 - val_y1_output_mae: 2.6089 - val_y2_output_loss: 13.8721 - val_y2_output_mae: 2.6221
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41.4274 - y1_output_loss: 20.1138 - y1_output_mae: 3.2603 - y2_output_loss: 21.2765 - y2_output_mae: 3.4244 - val_loss: 22.0324 - val_y1_output_loss: 8.9590 - val_y1_output_mae: 2.2233 - val_y2_output_loss: 13.1563 - val_y2_output_mae: 2.5305
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.6727 - y1_output_loss: 18.4132 - y1_output_mae: 3.1453 - y2_output_loss: 19.2328 - y2_output_mae: 3.2635 - val_loss: 24.1815 - val_y1_output_loss: 11.1841 - val_y1_output_mae: 2.5643 - val_y2_output_loss: 13.1272 - val_y2_output_mae: 2.4912
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.6583 - y1_output_loss: 16.1046 - y1_output_mae: 2.9654 - y2_output_loss: 20.5119 - y2_output_mae: 3.2964 - val_loss: 18.5844 - val_y1_output_loss: 8.0323 - val_y1_output_mae: 2.0322 - val_y2_output_loss: 10.5598 - val_y2_output_mae: 2.1775
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.6477 - y1_output_loss: 15.3782 - y1_output_mae: 2.9037 - y2_output_loss: 21.3240 - y2_output_mae: 3.3381 - val_loss: 21.3457 - val_y1_output_loss: 9.7264 - val_y1_output_mae: 2.4312 - val_y2_output_loss: 11.7234 - val_y2_output_mae: 2.3690
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.4274 - y1_output_loss: 16.8169 - y1_output_mae: 3.0424 - y2_output_loss: 17.7564 - y2_output_mae: 3.1399 - val_loss: 17.5087 - val_y1_output_loss: 8.2072 - val_y1_output_mae: 2.1520 - val_y2_output_loss: 9.2977 - val_y2_output_mae: 2.0423
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.7463 - y1_output_loss: 13.2353 - y1_output_mae: 2.7270 - y2_output_loss: 16.7806 - y2_output_mae: 3.1098 - val_loss: 22.5323 - val_y1_output_loss: 10.3432 - val_y1_output_mae: 2.5026 - val_y2_output_loss: 12.3316 - val_y2_output_mae: 2.4498
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.4623 - y1_output_loss: 15.9841 - y1_output_mae: 3.0004 - y2_output_loss: 20.3759 - y2_output_mae: 3.3972 - val_loss: 26.6822 - val_y1_output_loss: 12.1738 - val_y1_output_mae: 2.7729 - val_y2_output_loss: 14.7706 - val_y2_output_mae: 2.7933
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.7242 - y1_output_loss: 15.1261 - y1_output_mae: 2.8503 - y2_output_loss: 19.6587 - y2_output_mae: 3.3435 - val_loss: 23.6607 - val_y1_output_loss: 11.5997 - val_y1_output_mae: 2.7045 - val_y2_output_loss: 12.2035 - val_y2_output_mae: 2.4726
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.8992 - y1_output_loss: 15.5802 - y1_output_mae: 2.9632 - y2_output_loss: 18.3713 - y2_output_mae: 3.1767 - val_loss: 24.6834 - val_y1_output_loss: 11.6711 - val_y1_output_mae: 2.6823 - val_y2_output_loss: 13.1927 - val_y2_output_mae: 2.5626
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.5762 - y1_output_loss: 17.3327 - y1_output_mae: 3.0266 - y2_output_loss: 20.1659 - y2_output_mae: 3.2770 - val_loss: 20.2768 - val_y1_output_loss: 9.5856 - val_y1_output_mae: 2.4048 - val_y2_output_loss: 10.7748 - val_y2_output_mae: 2.3102
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.9801 - y1_output_loss: 15.6097 - y1_output_mae: 2.8501 - y2_output_loss: 19.6048 - y2_output_mae: 3.2478 - val_loss: 22.7555 - val_y1_output_loss: 9.8930 - val_y1_output_mae: 2.4538 - val_y2_output_loss: 13.0211 - val_y2_output_mae: 2.5845
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.3043 - y1_output_loss: 15.7910 - y1_output_mae: 3.0410 - y2_output_loss: 20.4786 - y2_output_mae: 3.3899 - val_loss: 19.3024 - val_y1_output_loss: 8.9428 - val_y1_output_mae: 2.3410 - val_y2_output_loss: 10.4781 - val_y2_output_mae: 2.2438
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.9550 - y1_output_loss: 15.0037 - y1_output_mae: 2.8493 - y2_output_loss: 18.1197 - y2_output_mae: 3.1201 - val_loss: 25.0462 - val_y1_output_loss: 10.6377 - val_y1_output_mae: 2.5651 - val_y2_output_loss: 14.5895 - val_y2_output_mae: 2.7229
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.6793 - y1_output_loss: 15.3201 - y1_output_mae: 2.8781 - y2_output_loss: 17.2815 - y2_output_mae: 3.1241 - val_loss: 28.6251 - val_y1_output_loss: 15.1025 - val_y1_output_mae: 3.1729 - val_y2_output_loss: 13.7474 - val_y2_output_mae: 2.7181
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.1729 - y1_output_loss: 15.7460 - y1_output_mae: 2.8897 - y2_output_loss: 20.4477 - y2_output_mae: 3.2513 - val_loss: 25.6802 - val_y1_output_loss: 10.8529 - val_y1_output_mae: 2.6303 - val_y2_output_loss: 15.0351 - val_y2_output_mae: 2.8597
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.1397 - y1_output_loss: 14.6099 - y1_output_mae: 2.8797 - y2_output_loss: 18.4874 - y2_output_mae: 3.2242 - val_loss: 24.1979 - val_y1_output_loss: 10.4637 - val_y1_output_mae: 2.5387 - val_y2_output_loss: 13.8993 - val_y2_output_mae: 2.6344
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.7888 - y1_output_loss: 14.9025 - y1_output_mae: 2.8430 - y2_output_loss: 17.8097 - y2_output_mae: 3.1210 - val_loss: 20.8656 - val_y1_output_loss: 9.2719 - val_y1_output_mae: 2.4413 - val_y2_output_loss: 11.7340 - val_y2_output_mae: 2.3910
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.0554 - y1_output_loss: 15.1845 - y1_output_mae: 2.8933 - y2_output_loss: 16.8649 - y2_output_mae: 3.1300 - val_loss: 29.1019 - val_y1_output_loss: 12.5586 - val_y1_output_mae: 2.8516 - val_y2_output_loss: 16.8430 - val_y2_output_mae: 3.0047
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.9445 - y1_output_loss: 14.0454 - y1_output_mae: 2.6937 - y2_output_loss: 15.8402 - y2_output_mae: 2.9352 - val_loss: 20.3351 - val_y1_output_loss: 7.1751 - val_y1_output_mae: 1.9872 - val_y2_output_loss: 13.2814 - val_y2_output_mae: 2.5480
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.3221 - y1_output_loss: 15.7528 - y1_output_mae: 2.9519 - y2_output_loss: 17.6095 - y2_output_mae: 3.1194 - val_loss: 25.0484 - val_y1_output_loss: 13.1485 - val_y1_output_mae: 2.9207 - val_y2_output_loss: 12.1538 - val_y2_output_mae: 2.5006
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.7685 - y1_output_loss: 14.7229 - y1_output_mae: 2.8374 - y2_output_loss: 17.0878 - y2_output_mae: 3.0084 - val_loss: 22.2670 - val_y1_output_loss: 9.2981 - val_y1_output_mae: 2.3565 - val_y2_output_loss: 13.0935 - val_y2_output_mae: 2.5800
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 36.0992 - y1_output_loss: 14.3092 - y1_output_mae: 2.7419 - y2_output_loss: 21.7075 - y2_output_mae: 3.3906 - val_loss: 26.7759 - val_y1_output_loss: 12.6239 - val_y1_output_mae: 2.8026 - val_y2_output_loss: 14.4660 - val_y2_output_mae: 2.6918
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.1653 - y1_output_loss: 15.0343 - y1_output_mae: 2.7789 - y2_output_loss: 15.0833 - y2_output_mae: 2.9500 - val_loss: 29.9136 - val_y1_output_loss: 14.9316 - val_y1_output_mae: 3.0601 - val_y2_output_loss: 15.3835 - val_y2_output_mae: 2.8057
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.7670 - y1_output_loss: 15.3218 - y1_output_mae: 2.8605 - y2_output_loss: 13.4002 - y2_output_mae: 2.8402 - val_loss: 22.2127 - val_y1_output_loss: 9.1476 - val_y1_output_mae: 2.4021 - val_y2_output_loss: 13.2275 - val_y2_output_mae: 2.6335
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.6977 - y1_output_loss: 12.5773 - y1_output_mae: 2.6284 - y2_output_loss: 18.0805 - y2_output_mae: 3.0993 - val_loss: 27.1109 - val_y1_output_loss: 11.7401 - val_y1_output_mae: 2.7601 - val_y2_output_loss: 15.6142 - val_y2_output_mae: 2.9272
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 35.1427 - y1_output_loss: 15.7612 - y1_output_mae: 2.8862 - y2_output_loss: 19.5448 - y2_output_mae: 3.2412 - val_loss: 28.3689 - val_y1_output_loss: 12.7785 - val_y1_output_mae: 2.8469 - val_y2_output_loss: 15.9236 - val_y2_output_mae: 2.9171
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 34.1800 - y1_output_loss: 15.2866 - y1_output_mae: 2.7446 - y2_output_loss: 18.8946 - y2_output_mae: 3.1847 - val_loss: 24.8691 - val_y1_output_loss: 11.5864 - val_y1_output_mae: 2.6777 - val_y2_output_loss: 13.6321 - val_y2_output_mae: 2.5978
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.9614 - y1_output_loss: 14.4546 - y1_output_mae: 2.6547 - y2_output_loss: 17.4894 - y2_output_mae: 3.1143 - val_loss: 21.5597 - val_y1_output_loss: 10.9526 - val_y1_output_mae: 2.6228 - val_y2_output_loss: 10.8140 - val_y2_output_mae: 2.2308
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33.8233 - y1_output_loss: 16.2914 - y1_output_mae: 2.9481 - y2_output_loss: 17.5711 - y2_output_mae: 3.0853 - val_loss: 16.4816 - val_y1_output_loss: 7.9014 - val_y1_output_mae: 2.1954 - val_y2_output_loss: 8.6791 - val_y2_output_mae: 1.9874
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.6394 - y1_output_loss: 13.5560 - y1_output_mae: 2.6642 - y2_output_loss: 15.9998 - y2_output_mae: 2.9940 - val_loss: 20.1310 - val_y1_output_loss: 10.0295 - val_y1_output_mae: 2.5477 - val_y2_output_loss: 10.2345 - val_y2_output_mae: 2.2604
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.7170 - y1_output_loss: 11.6499 - y1_output_mae: 2.5287 - y2_output_loss: 13.1481 - y2_output_mae: 2.6539 - val_loss: 17.6682 - val_y1_output_loss: 8.2512 - val_y1_output_mae: 2.2415 - val_y2_output_loss: 9.4861 - val_y2_output_mae: 2.1106
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 32.5531 - y1_output_loss: 14.9528 - y1_output_mae: 2.6797 - y2_output_loss: 17.5404 - y2_output_mae: 3.0849 - val_loss: 25.9739 - val_y1_output_loss: 12.3738 - val_y1_output_mae: 2.8155 - val_y2_output_loss: 13.9267 - val_y2_output_mae: 2.7007
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.6642 - y1_output_loss: 15.1161 - y1_output_mae: 2.7788 - y2_output_loss: 15.5160 - y2_output_mae: 2.7623 - val_loss: 33.9777 - val_y1_output_loss: 16.8800 - val_y1_output_mae: 3.3243 - val_y2_output_loss: 17.5562 - val_y2_output_mae: 3.1758
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30.4682 - y1_output_loss: 14.1037 - y1_output_mae: 2.8138 - y2_output_loss: 16.2938 - y2_output_mae: 2.9988 - val_loss: 30.6348 - val_y1_output_loss: 15.3451 - val_y1_output_mae: 3.1272 - val_y2_output_loss: 15.6588 - val_y2_output_mae: 2.9130
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.7454 - y1_output_loss: 12.6911 - y1_output_mae: 2.6083 - y2_output_loss: 16.9814 - y2_output_mae: 2.9321 - val_loss: 25.2166 - val_y1_output_loss: 9.5477 - val_y1_output_mae: 2.4737 - val_y2_output_loss: 15.9767 - val_y2_output_mae: 3.0583
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.7141 - y1_output_loss: 13.2222 - y1_output_mae: 2.6051 - y2_output_loss: 13.4341 - y2_output_mae: 2.7399 - val_loss: 20.4848 - val_y1_output_loss: 10.2681 - val_y1_output_mae: 2.5394 - val_y2_output_loss: 10.4464 - val_y2_output_mae: 2.2621
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.5211 - y1_output_loss: 12.3652 - y1_output_mae: 2.6320 - y2_output_loss: 16.2434 - y2_output_mae: 3.0089 - val_loss: 33.1362 - val_y1_output_loss: 16.2053 - val_y1_output_mae: 3.1859 - val_y2_output_loss: 17.3427 - val_y2_output_mae: 3.0771
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.0915 - y1_output_loss: 12.3042 - y1_output_mae: 2.4363 - y2_output_loss: 14.7326 - y2_output_mae: 2.7359 - val_loss: 34.1510 - val_y1_output_loss: 15.0641 - val_y1_output_mae: 3.1042 - val_y2_output_loss: 19.5160 - val_y2_output_mae: 3.4090
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.9963 - y1_output_loss: 14.3030 - y1_output_mae: 2.7030 - y2_output_loss: 14.9142 - y2_output_mae: 2.9122 - val_loss: 27.3195 - val_y1_output_loss: 12.4828 - val_y1_output_mae: 2.7040 - val_y2_output_loss: 15.2369 - val_y2_output_mae: 2.7267
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 28.4859 - y1_output_loss: 12.7199 - y1_output_mae: 2.6685 - y2_output_loss: 15.7566 - y2_output_mae: 2.9344 - val_loss: 28.8662 - val_y1_output_loss: 13.4850 - val_y1_output_mae: 2.9980 - val_y2_output_loss: 15.6671 - val_y2_output_mae: 2.9652
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.0427 - y1_output_loss: 12.3073 - y1_output_mae: 2.6017 - y2_output_loss: 14.7488 - y2_output_mae: 2.8262 - val_loss: 30.4597 - val_y1_output_loss: 12.7266 - val_y1_output_mae: 2.8051 - val_y2_output_loss: 18.0852 - val_y2_output_mae: 3.1376
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 31.1004 - y1_output_loss: 13.5133 - y1_output_mae: 2.5523 - y2_output_loss: 17.6185 - y2_output_mae: 2.9769 - val_loss: 40.8990 - val_y1_output_loss: 19.7696 - val_y1_output_mae: 3.4913 - val_y2_output_loss: 21.8162 - val_y2_output_mae: 3.5718
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.5397 - y1_output_loss: 13.6057 - y1_output_mae: 2.6129 - y2_output_loss: 15.9703 - y2_output_mae: 2.8500 - val_loss: 26.7190 - val_y1_output_loss: 15.8065 - val_y1_output_mae: 3.1021 - val_y2_output_loss: 11.2588 - val_y2_output_mae: 2.3311
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.2975 - y1_output_loss: 12.2286 - y1_output_mae: 2.5482 - y2_output_loss: 13.9781 - y2_output_mae: 2.7843 - val_loss: 25.8660 - val_y1_output_loss: 12.4831 - val_y1_output_mae: 2.7888 - val_y2_output_loss: 13.7184 - val_y2_output_mae: 2.6844
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.2957 - y1_output_loss: 11.8748 - y1_output_mae: 2.5310 - y2_output_loss: 17.4315 - y2_output_mae: 3.0788 - val_loss: 28.0628 - val_y1_output_loss: 13.7889 - val_y1_output_mae: 2.9772 - val_y2_output_loss: 14.6622 - val_y2_output_mae: 2.8387
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.2587 - y1_output_loss: 10.3819 - y1_output_mae: 2.3321 - y2_output_loss: 12.8514 - y2_output_mae: 2.6499 - val_loss: 22.5503 - val_y1_output_loss: 13.6848 - val_y1_output_mae: 2.9205 - val_y2_output_loss: 9.1661 - val_y2_output_mae: 2.0656
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.5842 - y1_output_loss: 13.5278 - y1_output_mae: 2.6588 - y2_output_loss: 16.0924 - y2_output_mae: 3.0457 - val_loss: 23.5350 - val_y1_output_loss: 11.1654 - val_y1_output_mae: 2.6393 - val_y2_output_loss: 12.7362 - val_y2_output_mae: 2.5605
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.5401 - y1_output_loss: 12.0356 - y1_output_mae: 2.5344 - y2_output_loss: 14.5438 - y2_output_mae: 2.7597 - val_loss: 43.5059 - val_y1_output_loss: 19.8245 - val_y1_output_mae: 3.4950 - val_y2_output_loss: 24.2874 - val_y2_output_mae: 3.7830
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 29.6905 - y1_output_loss: 12.5482 - y1_output_mae: 2.5086 - y2_output_loss: 17.1699 - y2_output_mae: 2.9745 - val_loss: 41.3775 - val_y1_output_loss: 20.1713 - val_y1_output_mae: 3.4736 - val_y2_output_loss: 21.9295 - val_y2_output_mae: 3.4356
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.4723 - y1_output_loss: 11.6278 - y1_output_mae: 2.4631 - y2_output_loss: 14.8224 - y2_output_mae: 2.8349 - val_loss: 33.6082 - val_y1_output_loss: 16.4460 - val_y1_output_mae: 3.2348 - val_y2_output_loss: 17.6291 - val_y2_output_mae: 3.0745
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27.1498 - y1_output_loss: 11.9663 - y1_output_mae: 2.4582 - y2_output_loss: 15.1659 - y2_output_mae: 2.8941 - val_loss: 44.2263 - val_y1_output_loss: 20.6166 - val_y1_output_mae: 3.6549 - val_y2_output_loss: 24.2388 - val_y2_output_mae: 3.8595
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.9394 - y1_output_loss: 11.8821 - y1_output_mae: 2.4680 - y2_output_loss: 15.1293 - y2_output_mae: 2.8837 - val_loss: 32.9722 - val_y1_output_loss: 16.1204 - val_y1_output_mae: 3.1531 - val_y2_output_loss: 17.3702 - val_y2_output_mae: 3.0783
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.1931 - y1_output_loss: 12.0663 - y1_output_mae: 2.4579 - y2_output_loss: 14.1206 - y2_output_mae: 2.7981 - val_loss: 29.9381 - val_y1_output_loss: 13.3136 - val_y1_output_mae: 2.8817 - val_y2_output_loss: 17.0988 - val_y2_output_mae: 3.0412
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 26.9820 - y1_output_loss: 10.6316 - y1_output_mae: 2.3567 - y2_output_loss: 16.3099 - y2_output_mae: 2.9429 - val_loss: 37.2108 - val_y1_output_loss: 15.7053 - val_y1_output_mae: 3.1160 - val_y2_output_loss: 22.0661 - val_y2_output_mae: 3.6171
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.9753 - y1_output_loss: 11.0535 - y1_output_mae: 2.3804 - y2_output_loss: 13.8756 - y2_output_mae: 2.7101 - val_loss: 39.8884 - val_y1_output_loss: 21.4345 - val_y1_output_mae: 3.6953 - val_y2_output_loss: 19.0371 - val_y2_output_mae: 3.3184
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.2549 - y1_output_loss: 11.0123 - y1_output_mae: 2.3981 - y2_output_loss: 13.2690 - y2_output_mae: 2.6358 - val_loss: 36.2962 - val_y1_output_loss: 16.5160 - val_y1_output_mae: 3.2526 - val_y2_output_loss: 20.3389 - val_y2_output_mae: 3.4800
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.2840 - y1_output_loss: 11.6399 - y1_output_mae: 2.4592 - y2_output_loss: 13.6094 - y2_output_mae: 2.7118 - val_loss: 30.3843 - val_y1_output_loss: 14.9741 - val_y1_output_mae: 2.9848 - val_y2_output_loss: 15.8674 - val_y2_output_mae: 2.9217
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.1478 - y1_output_loss: 12.1184 - y1_output_mae: 2.5516 - y2_output_loss: 13.0044 - y2_output_mae: 2.6303 - val_loss: 45.6949 - val_y1_output_loss: 23.3344 - val_y1_output_mae: 3.9092 - val_y2_output_loss: 23.0277 - val_y2_output_mae: 3.6857
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.5258 - y1_output_loss: 11.9848 - y1_output_mae: 2.4882 - y2_output_loss: 13.4713 - y2_output_mae: 2.6862 - val_loss: 46.2181 - val_y1_output_loss: 24.2590 - val_y1_output_mae: 3.8583 - val_y2_output_loss: 22.7150 - val_y2_output_mae: 3.5821
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.4779 - y1_output_loss: 11.8656 - y1_output_mae: 2.4876 - y2_output_loss: 13.6640 - y2_output_mae: 2.6928 - val_loss: 43.7306 - val_y1_output_loss: 22.2661 - val_y1_output_mae: 3.7863 - val_y2_output_loss: 22.1196 - val_y2_output_mae: 3.6411
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.9497 - y1_output_loss: 10.7350 - y1_output_mae: 2.3780 - y2_output_loss: 13.1633 - y2_output_mae: 2.6609 - val_loss: 41.2673 - val_y1_output_loss: 17.7683 - val_y1_output_mae: 3.2267 - val_y2_output_loss: 24.1118 - val_y2_output_mae: 3.7143
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.7522 - y1_output_loss: 10.0522 - y1_output_mae: 2.3700 - y2_output_loss: 12.6402 - y2_output_mae: 2.5724 - val_loss: 39.3849 - val_y1_output_loss: 21.8594 - val_y1_output_mae: 3.6553 - val_y2_output_loss: 18.1285 - val_y2_output_mae: 3.1376
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.0528 - y1_output_loss: 9.2745 - y1_output_mae: 2.2674 - y2_output_loss: 11.8781 - y2_output_mae: 2.5791 - val_loss: 41.0822 - val_y1_output_loss: 19.1097 - val_y1_output_mae: 3.4478 - val_y2_output_loss: 22.6959 - val_y2_output_mae: 3.6668
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.4755 - y1_output_loss: 12.1486 - y1_output_mae: 2.5022 - y2_output_loss: 12.4076 - y2_output_mae: 2.5743 - val_loss: 37.9244 - val_y1_output_loss: 20.4508 - val_y1_output_mae: 3.5549 - val_y2_output_loss: 18.1637 - val_y2_output_mae: 3.1670
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.6793 - y1_output_loss: 11.3761 - y1_output_mae: 2.4451 - y2_output_loss: 13.2435 - y2_output_mae: 2.6471 - val_loss: 41.3499 - val_y1_output_loss: 23.2015 - val_y1_output_mae: 3.7832 - val_y2_output_loss: 18.8470 - val_y2_output_mae: 3.2286
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.0724 - y1_output_loss: 11.3927 - y1_output_mae: 2.4285 - y2_output_loss: 12.6369 - y2_output_mae: 2.5527 - val_loss: 39.3167 - val_y1_output_loss: 20.3653 - val_y1_output_mae: 3.4856 - val_y2_output_loss: 19.6364 - val_y2_output_mae: 3.2871
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.7230 - y1_output_loss: 9.9603 - y1_output_mae: 2.2295 - y2_output_loss: 11.7457 - y2_output_mae: 2.5757 - val_loss: 39.4947 - val_y1_output_loss: 20.1174 - val_y1_output_mae: 3.4773 - val_y2_output_loss: 20.0440 - val_y2_output_mae: 3.3524
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.4954 - y1_output_loss: 10.6379 - y1_output_mae: 2.3492 - y2_output_loss: 12.8223 - y2_output_mae: 2.6092 - val_loss: 30.5409 - val_y1_output_loss: 15.5847 - val_y1_output_mae: 3.0443 - val_y2_output_loss: 15.4683 - val_y2_output_mae: 2.8508
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.1154 - y1_output_loss: 9.6129 - y1_output_mae: 2.2138 - y2_output_loss: 11.5751 - y2_output_mae: 2.4454 - val_loss: 34.8523 - val_y1_output_loss: 14.0795 - val_y1_output_mae: 2.8333 - val_y2_output_loss: 21.3049 - val_y2_output_mae: 3.4843
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.1350 - y1_output_loss: 10.2316 - y1_output_mae: 2.3289 - y2_output_loss: 12.9975 - y2_output_mae: 2.5865 - val_loss: 39.8323 - val_y1_output_loss: 23.1320 - val_y1_output_mae: 3.8016 - val_y2_output_loss: 17.3799 - val_y2_output_mae: 3.0629
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.3118 - y1_output_loss: 9.7278 - y1_output_mae: 2.2230 - y2_output_loss: 12.5344 - y2_output_mae: 2.5878 - val_loss: 35.0161 - val_y1_output_loss: 21.4166 - val_y1_output_mae: 3.5143 - val_y2_output_loss: 14.2337 - val_y2_output_mae: 2.6968
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.1293 - y1_output_loss: 9.2034 - y1_output_mae: 2.1941 - y2_output_loss: 10.9229 - y2_output_mae: 2.4578 - val_loss: 52.3134 - val_y1_output_loss: 28.4954 - val_y1_output_mae: 4.2046 - val_y2_output_loss: 24.7003 - val_y2_output_mae: 3.8385
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.7161 - y1_output_loss: 9.7468 - y1_output_mae: 2.2618 - y2_output_loss: 13.0093 - y2_output_mae: 2.5229 - val_loss: 42.6856 - val_y1_output_loss: 21.7110 - val_y1_output_mae: 3.5793 - val_y2_output_loss: 21.6593 - val_y2_output_mae: 3.5023
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.3555 - y1_output_loss: 11.1778 - y1_output_mae: 2.4067 - y2_output_loss: 12.1858 - y2_output_mae: 2.5185 - val_loss: 38.4889 - val_y1_output_loss: 19.4218 - val_y1_output_mae: 3.3941 - val_y2_output_loss: 19.7039 - val_y2_output_mae: 3.3060
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.0407 - y1_output_loss: 10.0149 - y1_output_mae: 2.3440 - y2_output_loss: 11.1376 - y2_output_mae: 2.4379 - val_loss: 38.5720 - val_y1_output_loss: 17.9664 - val_y1_output_mae: 3.3235 - val_y2_output_loss: 21.2595 - val_y2_output_mae: 3.4588
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25.3357 - y1_output_loss: 11.5904 - y1_output_mae: 2.4397 - y2_output_loss: 13.7416 - y2_output_mae: 2.5930 - val_loss: 45.9950 - val_y1_output_loss: 24.9169 - val_y1_output_mae: 3.8892 - val_y2_output_loss: 21.8381 - val_y2_output_mae: 3.4749
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.2488 - y1_output_loss: 9.9305 - y1_output_mae: 2.2245 - y2_output_loss: 9.3616 - y2_output_mae: 2.2586 - val_loss: 47.3320 - val_y1_output_loss: 28.8223 - val_y1_output_mae: 4.2052 - val_y2_output_loss: 19.2791 - val_y2_output_mae: 3.1583
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 24.1928 - y1_output_loss: 10.9852 - y1_output_mae: 2.3060 - y2_output_loss: 13.1829 - y2_output_mae: 2.6893 - val_loss: 46.0492 - val_y1_output_loss: 24.9963 - val_y1_output_mae: 3.9446 - val_y2_output_loss: 21.8567 - val_y2_output_mae: 3.4803
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.0234 - y1_output_loss: 9.8429 - y1_output_mae: 2.2576 - y2_output_loss: 12.1029 - y2_output_mae: 2.5408 - val_loss: 37.2953 - val_y1_output_loss: 18.3403 - val_y1_output_mae: 3.2753 - val_y2_output_loss: 19.6404 - val_y2_output_mae: 3.2253
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.2947 - y1_output_loss: 10.4595 - y1_output_mae: 2.3253 - y2_output_loss: 10.8448 - y2_output_mae: 2.4638 - val_loss: 50.4809 - val_y1_output_loss: 27.5213 - val_y1_output_mae: 4.1562 - val_y2_output_loss: 23.7389 - val_y2_output_mae: 3.6430
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.6802 - y1_output_loss: 10.3005 - y1_output_mae: 2.3440 - y2_output_loss: 10.3492 - y2_output_mae: 2.3257 - val_loss: 49.8094 - val_y1_output_loss: 24.9737 - val_y1_output_mae: 3.9481 - val_y2_output_loss: 25.6558 - val_y2_output_mae: 3.8739
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.9176 - y1_output_loss: 9.1248 - y1_output_mae: 2.1799 - y2_output_loss: 10.8130 - y2_output_mae: 2.4744 - val_loss: 45.1068 - val_y1_output_loss: 26.0586 - val_y1_output_mae: 4.0273 - val_y2_output_loss: 19.8518 - val_y2_output_mae: 3.2857
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 22.1831 - y1_output_loss: 9.8324 - y1_output_mae: 2.2613 - y2_output_loss: 12.3407 - y2_output_mae: 2.5220 - val_loss: 47.5915 - val_y1_output_loss: 24.5907 - val_y1_output_mae: 3.8334 - val_y2_output_loss: 23.8662 - val_y2_output_mae: 3.6864
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 23.1043 - y1_output_loss: 8.9303 - y1_output_mae: 2.0959 - y2_output_loss: 14.2320 - y2_output_mae: 2.6448 - val_loss: 43.7096 - val_y1_output_loss: 22.4354 - val_y1_output_mae: 3.6717 - val_y2_output_loss: 22.0215 - val_y2_output_mae: 3.5283
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.9405 - y1_output_loss: 7.5783 - y1_output_mae: 1.9938 - y2_output_loss: 10.3644 - y2_output_mae: 2.3243 - val_loss: 47.1436 - val_y1_output_loss: 28.5848 - val_y1_output_mae: 4.1385 - val_y2_output_loss: 19.3609 - val_y2_output_mae: 3.1939
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.2410 - y1_output_loss: 9.8332 - y1_output_mae: 2.2078 - y2_output_loss: 10.4155 - y2_output_mae: 2.4049 - val_loss: 44.0853 - val_y1_output_loss: 27.0682 - val_y1_output_mae: 4.1167 - val_y2_output_loss: 17.8169 - val_y2_output_mae: 3.0864
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.7233 - y1_output_loss: 8.3004 - y1_output_mae: 2.0721 - y2_output_loss: 10.3755 - y2_output_mae: 2.3200 - val_loss: 37.6009 - val_y1_output_loss: 20.9188 - val_y1_output_mae: 3.5856 - val_y2_output_loss: 17.3559 - val_y2_output_mae: 3.0650
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.2798 - y1_output_loss: 10.3540 - y1_output_mae: 2.2482 - y2_output_loss: 10.8892 - y2_output_mae: 2.4372 - val_loss: 38.0993 - val_y1_output_loss: 20.2750 - val_y1_output_mae: 3.4859 - val_y2_output_loss: 18.5656 - val_y2_output_mae: 3.1415
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.6711 - y1_output_loss: 7.9267 - y1_output_mae: 2.0000 - y2_output_loss: 11.6957 - y2_output_mae: 2.3790 - val_loss: 39.5919 - val_y1_output_loss: 21.7261 - val_y1_output_mae: 3.5618 - val_y2_output_loss: 18.6238 - val_y2_output_mae: 3.1387
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.5554 - y1_output_loss: 8.2516 - y1_output_mae: 2.0367 - y2_output_loss: 10.2540 - y2_output_mae: 2.3111 - val_loss: 35.5300 - val_y1_output_loss: 16.5976 - val_y1_output_mae: 3.0087 - val_y2_output_loss: 19.5980 - val_y2_output_mae: 3.2453
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7880 - y1_output_loss: 9.4547 - y1_output_mae: 2.2065 - y2_output_loss: 10.2971 - y2_output_mae: 2.3254 - val_loss: 42.7590 - val_y1_output_loss: 20.6198 - val_y1_output_mae: 3.5027 - val_y2_output_loss: 22.9226 - val_y2_output_mae: 3.6287
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.4219 - y1_output_loss: 9.9406 - y1_output_mae: 2.2327 - y2_output_loss: 10.4672 - y2_output_mae: 2.3564 - val_loss: 41.3250 - val_y1_output_loss: 22.2780 - val_y1_output_mae: 3.7212 - val_y2_output_loss: 19.7451 - val_y2_output_mae: 3.3458
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.1283 - y1_output_loss: 8.6314 - y1_output_mae: 2.1436 - y2_output_loss: 10.4581 - y2_output_mae: 2.3066 - val_loss: 48.2590 - val_y1_output_loss: 24.2881 - val_y1_output_mae: 3.7707 - val_y2_output_loss: 24.8382 - val_y2_output_mae: 3.7779
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20.3048 - y1_output_loss: 9.9827 - y1_output_mae: 2.0811 - y2_output_loss: 10.3001 - y2_output_mae: 2.2894 - val_loss: 41.8298 - val_y1_output_loss: 22.1821 - val_y1_output_mae: 3.6645 - val_y2_output_loss: 20.4227 - val_y2_output_mae: 3.3080
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.2157 - y1_output_loss: 8.4294 - y1_output_mae: 2.0128 - y2_output_loss: 9.7219 - y2_output_mae: 2.2934 - val_loss: 46.1223 - val_y1_output_loss: 23.2624 - val_y1_output_mae: 3.7419 - val_y2_output_loss: 23.6529 - val_y2_output_mae: 3.5847
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.5417 - y1_output_loss: 6.8104 - y1_output_mae: 1.8683 - y2_output_loss: 10.6857 - y2_output_mae: 2.3401 - val_loss: 43.1380 - val_y1_output_loss: 23.8730 - val_y1_output_mae: 3.8105 - val_y2_output_loss: 19.9833 - val_y2_output_mae: 3.2639
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.4562 - y1_output_loss: 8.3063 - y1_output_mae: 2.0651 - y2_output_loss: 10.1564 - y2_output_mae: 2.3185 - val_loss: 47.5795 - val_y1_output_loss: 24.8130 - val_y1_output_mae: 3.8477 - val_y2_output_loss: 23.4842 - val_y2_output_mae: 3.6048
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.8091 - y1_output_loss: 10.3708 - y1_output_mae: 2.2292 - y2_output_loss: 11.4216 - y2_output_mae: 2.3961 - val_loss: 43.4367 - val_y1_output_loss: 23.2384 - val_y1_output_mae: 3.7239 - val_y2_output_loss: 20.9624 - val_y2_output_mae: 3.4265
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.1470 - y1_output_loss: 8.3411 - y1_output_mae: 2.0923 - y2_output_loss: 8.7835 - y2_output_mae: 2.2037 - val_loss: 51.5934 - val_y1_output_loss: 25.5862 - val_y1_output_mae: 3.8086 - val_y2_output_loss: 26.9581 - val_y2_output_mae: 3.8465
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19.7776 - y1_output_loss: 8.5235 - y1_output_mae: 2.1160 - y2_output_loss: 11.2625 - y2_output_mae: 2.3489 - val_loss: 39.6411 - val_y1_output_loss: 22.7532 - val_y1_output_mae: 3.7303 - val_y2_output_loss: 17.6317 - val_y2_output_mae: 3.1100
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.3643 - y1_output_loss: 7.6945 - y1_output_mae: 1.9179 - y2_output_loss: 10.6471 - y2_output_mae: 2.3165 - val_loss: 36.4965 - val_y1_output_loss: 18.5148 - val_y1_output_mae: 3.2390 - val_y2_output_loss: 18.6869 - val_y2_output_mae: 3.1610
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.0938 - y1_output_loss: 8.0857 - y1_output_mae: 1.9901 - y2_output_loss: 9.9792 - y2_output_mae: 2.2088 - val_loss: 46.4654 - val_y1_output_loss: 24.6249 - val_y1_output_mae: 3.7461 - val_y2_output_loss: 22.7458 - val_y2_output_mae: 3.5134
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.0243 - y1_output_loss: 9.3701 - y1_output_mae: 2.0629 - y2_output_loss: 7.6138 - y2_output_mae: 2.0341 - val_loss: 63.4250 - val_y1_output_loss: 36.3404 - val_y1_output_mae: 4.7772 - val_y2_output_loss: 28.1687 - val_y2_output_mae: 3.9810
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.9153 - y1_output_loss: 8.6130 - y1_output_mae: 2.0996 - y2_output_loss: 9.2468 - y2_output_mae: 2.1996 - val_loss: 64.4701 - val_y1_output_loss: 34.0651 - val_y1_output_mae: 4.6214 - val_y2_output_loss: 31.4418 - val_y2_output_mae: 4.3357
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.2794 - y1_output_loss: 7.9407 - y1_output_mae: 1.9501 - y2_output_loss: 8.3870 - y2_output_mae: 2.0697 - val_loss: 49.8629 - val_y1_output_loss: 27.0907 - val_y1_output_mae: 3.9726 - val_y2_output_loss: 23.6497 - val_y2_output_mae: 3.5566
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.1855 - y1_output_loss: 6.5099 - y1_output_mae: 1.8130 - y2_output_loss: 9.6246 - y2_output_mae: 2.2181 - val_loss: 50.5393 - val_y1_output_loss: 29.4488 - val_y1_output_mae: 4.2310 - val_y2_output_loss: 21.9354 - val_y2_output_mae: 3.4510
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.8967 - y1_output_loss: 7.8190 - y1_output_mae: 2.0399 - y2_output_loss: 11.0313 - y2_output_mae: 2.3826 - val_loss: 48.0685 - val_y1_output_loss: 28.1466 - val_y1_output_mae: 4.0707 - val_y2_output_loss: 20.7505 - val_y2_output_mae: 3.2676
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.1558 - y1_output_loss: 7.7262 - y1_output_mae: 1.9440 - y2_output_loss: 10.5065 - y2_output_mae: 2.3242 - val_loss: 38.5947 - val_y1_output_loss: 22.1818 - val_y1_output_mae: 3.6277 - val_y2_output_loss: 17.0832 - val_y2_output_mae: 2.9386
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.5564 - y1_output_loss: 7.7800 - y1_output_mae: 1.9793 - y2_output_loss: 9.7276 - y2_output_mae: 2.2487 - val_loss: 46.4585 - val_y1_output_loss: 26.7068 - val_y1_output_mae: 4.0325 - val_y2_output_loss: 20.4718 - val_y2_output_mae: 3.2939
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.9288 - y1_output_loss: 7.1812 - y1_output_mae: 1.9022 - y2_output_loss: 11.6870 - y2_output_mae: 2.4496 - val_loss: 51.5773 - val_y1_output_loss: 32.2524 - val_y1_output_mae: 4.4933 - val_y2_output_loss: 20.1535 - val_y2_output_mae: 3.2891
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.0893 - y1_output_loss: 6.8160 - y1_output_mae: 1.8203 - y2_output_loss: 9.3424 - y2_output_mae: 2.1343 - val_loss: 53.7984 - val_y1_output_loss: 31.0115 - val_y1_output_mae: 4.4039 - val_y2_output_loss: 23.6868 - val_y2_output_mae: 3.6305
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.2845 - y1_output_loss: 7.5642 - y1_output_mae: 1.9512 - y2_output_loss: 9.6763 - y2_output_mae: 2.2855 - val_loss: 59.3025 - val_y1_output_loss: 32.3915 - val_y1_output_mae: 4.3934 - val_y2_output_loss: 27.8865 - val_y2_output_mae: 3.9069
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.7233 - y1_output_loss: 7.3485 - y1_output_mae: 1.8722 - y2_output_loss: 8.4166 - y2_output_mae: 2.0967 - val_loss: 45.8338 - val_y1_output_loss: 24.3880 - val_y1_output_mae: 3.7476 - val_y2_output_loss: 22.3247 - val_y2_output_mae: 3.4724
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.2962 - y1_output_loss: 8.3596 - y1_output_mae: 2.0443 - y2_output_loss: 9.8862 - y2_output_mae: 2.1787 - val_loss: 61.1659 - val_y1_output_loss: 33.7271 - val_y1_output_mae: 4.5103 - val_y2_output_loss: 28.3714 - val_y2_output_mae: 3.9185
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.5760 - y1_output_loss: 8.1980 - y1_output_mae: 2.0005 - y2_output_loss: 9.3832 - y2_output_mae: 2.1277 - val_loss: 63.2585 - val_y1_output_loss: 34.3226 - val_y1_output_mae: 4.5809 - val_y2_output_loss: 29.9623 - val_y2_output_mae: 4.1280
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.5186 - y1_output_loss: 6.6362 - y1_output_mae: 1.8583 - y2_output_loss: 8.8595 - y2_output_mae: 2.1714 - val_loss: 49.4288 - val_y1_output_loss: 26.4195 - val_y1_output_mae: 3.9093 - val_y2_output_loss: 23.9305 - val_y2_output_mae: 3.6254
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.0302 - y1_output_loss: 7.5777 - y1_output_mae: 1.8985 - y2_output_loss: 8.4049 - y2_output_mae: 2.0618 - val_loss: 55.1685 - val_y1_output_loss: 34.6531 - val_y1_output_mae: 4.5935 - val_y2_output_loss: 21.4218 - val_y2_output_mae: 3.3974
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.1056 - y1_output_loss: 6.9270 - y1_output_mae: 1.8813 - y2_output_loss: 8.1348 - y2_output_mae: 2.0903 - val_loss: 52.3304 - val_y1_output_loss: 30.7194 - val_y1_output_mae: 4.3263 - val_y2_output_loss: 22.4929 - val_y2_output_mae: 3.4979
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.1057 - y1_output_loss: 7.1529 - y1_output_mae: 1.8844 - y2_output_loss: 7.9172 - y2_output_mae: 2.0800 - val_loss: 61.8491 - val_y1_output_loss: 30.5518 - val_y1_output_mae: 4.2961 - val_y2_output_loss: 32.3619 - val_y2_output_mae: 4.3401
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 17.3024 - y1_output_loss: 6.8559 - y1_output_mae: 1.8057 - y2_output_loss: 10.5158 - y2_output_mae: 2.2419 - val_loss: 54.4436 - val_y1_output_loss: 30.7443 - val_y1_output_mae: 4.3191 - val_y2_output_loss: 24.5344 - val_y2_output_mae: 3.6904
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.5681 - y1_output_loss: 6.3454 - y1_output_mae: 1.7473 - y2_output_loss: 9.2219 - y2_output_mae: 2.1450 - val_loss: 58.1737 - val_y1_output_loss: 31.6255 - val_y1_output_mae: 4.3049 - val_y2_output_loss: 27.4498 - val_y2_output_mae: 3.9546
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 18.4705 - y1_output_loss: 8.0155 - y1_output_mae: 1.9782 - y2_output_loss: 10.4287 - y2_output_mae: 2.1665 - val_loss: 50.6685 - val_y1_output_loss: 29.8194 - val_y1_output_mae: 4.1832 - val_y2_output_loss: 21.7248 - val_y2_output_mae: 3.3970
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.6646 - y1_output_loss: 5.9569 - y1_output_mae: 1.7623 - y2_output_loss: 8.6927 - y2_output_mae: 2.1924 - val_loss: 54.4587 - val_y1_output_loss: 28.1405 - val_y1_output_mae: 4.0649 - val_y2_output_loss: 27.2197 - val_y2_output_mae: 3.9557
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.4275 - y1_output_loss: 6.0640 - y1_output_mae: 1.7457 - y2_output_loss: 9.3375 - y2_output_mae: 2.1744 - val_loss: 67.5183 - val_y1_output_loss: 36.2006 - val_y1_output_mae: 4.6211 - val_y2_output_loss: 32.5598 - val_y2_output_mae: 4.3155
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.0492 - y1_output_loss: 6.8384 - y1_output_mae: 1.8185 - y2_output_loss: 8.2128 - y2_output_mae: 2.1017 - val_loss: 54.2332 - val_y1_output_loss: 32.1926 - val_y1_output_mae: 4.3951 - val_y2_output_loss: 23.0304 - val_y2_output_mae: 3.5393
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.7710 - y1_output_loss: 6.3730 - y1_output_mae: 1.8117 - y2_output_loss: 8.3962 - y2_output_mae: 2.0745 - val_loss: 58.3521 - val_y1_output_loss: 36.2191 - val_y1_output_mae: 4.7421 - val_y2_output_loss: 23.1291 - val_y2_output_mae: 3.6232
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.5340 - y1_output_loss: 6.7409 - y1_output_mae: 1.8135 - y2_output_loss: 9.8069 - y2_output_mae: 2.1999 - val_loss: 52.8165 - val_y1_output_loss: 36.9802 - val_y1_output_mae: 4.7558 - val_y2_output_loss: 16.7910 - val_y2_output_mae: 2.9242
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.7856 - y1_output_loss: 6.6058 - y1_output_mae: 1.8265 - y2_output_loss: 7.1257 - y2_output_mae: 1.9520 - val_loss: 65.4928 - val_y1_output_loss: 36.2619 - val_y1_output_mae: 4.6333 - val_y2_output_loss: 30.3729 - val_y2_output_mae: 4.1080
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 15.1669 - y1_output_loss: 6.5879 - y1_output_mae: 1.8075 - y2_output_loss: 8.7758 - y2_output_mae: 2.1031 - val_loss: 52.0566 - val_y1_output_loss: 27.8247 - val_y1_output_mae: 4.0134 - val_y2_output_loss: 25.2141 - val_y2_output_mae: 3.7408
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.8215 - y1_output_loss: 5.7747 - y1_output_mae: 1.7408 - y2_output_loss: 8.0284 - y2_output_mae: 2.1393 - val_loss: 39.4660 - val_y1_output_loss: 23.0790 - val_y1_output_mae: 3.6411 - val_y2_output_loss: 17.0946 - val_y2_output_mae: 3.0220
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.3481 - y1_output_loss: 7.1433 - y1_output_mae: 1.8848 - y2_output_loss: 7.1762 - y2_output_mae: 1.9692 - val_loss: 59.9050 - val_y1_output_loss: 35.2033 - val_y1_output_mae: 4.6150 - val_y2_output_loss: 25.6699 - val_y2_output_mae: 3.7427
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.6355 - y1_output_loss: 6.8119 - y1_output_mae: 1.7799 - y2_output_loss: 9.8011 - y2_output_mae: 2.1745 - val_loss: 58.3220 - val_y1_output_loss: 32.3021 - val_y1_output_mae: 4.4432 - val_y2_output_loss: 27.0380 - val_y2_output_mae: 3.8960
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.9433 - y1_output_loss: 6.7515 - y1_output_mae: 1.7406 - y2_output_loss: 8.2272 - y2_output_mae: 1.9775 - val_loss: 59.6939 - val_y1_output_loss: 27.8144 - val_y1_output_mae: 4.0765 - val_y2_output_loss: 32.8506 - val_y2_output_mae: 4.3652
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.2766 - y1_output_loss: 6.5124 - y1_output_mae: 1.7394 - y2_output_loss: 9.7425 - y2_output_mae: 2.1310 - val_loss: 58.1970 - val_y1_output_loss: 29.0978 - val_y1_output_mae: 4.1208 - val_y2_output_loss: 30.1220 - val_y2_output_mae: 4.0848
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.8915 - y1_output_loss: 6.5046 - y1_output_mae: 1.8625 - y2_output_loss: 10.3651 - y2_output_mae: 2.2712 - val_loss: 67.2508 - val_y1_output_loss: 39.5509 - val_y1_output_mae: 4.9930 - val_y2_output_loss: 28.7978 - val_y2_output_mae: 4.0442
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.1550 - y1_output_loss: 6.5090 - y1_output_mae: 1.7594 - y2_output_loss: 7.5979 - y2_output_mae: 1.9868 - val_loss: 61.3912 - val_y1_output_loss: 32.2363 - val_y1_output_mae: 4.4090 - val_y2_output_loss: 30.1082 - val_y2_output_mae: 4.1159
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.8943 - y1_output_loss: 5.3162 - y1_output_mae: 1.6515 - y2_output_loss: 8.6218 - y2_output_mae: 2.0580 - val_loss: 61.2287 - val_y1_output_loss: 35.4050 - val_y1_output_mae: 4.6862 - val_y2_output_loss: 26.7332 - val_y2_output_mae: 3.8721
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.2274 - y1_output_loss: 6.3584 - y1_output_mae: 1.7553 - y2_output_loss: 7.8786 - y2_output_mae: 1.9477 - val_loss: 51.1056 - val_y1_output_loss: 29.0214 - val_y1_output_mae: 4.1951 - val_y2_output_loss: 22.9273 - val_y2_output_mae: 3.5755
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.8095 - y1_output_loss: 5.3345 - y1_output_mae: 1.5809 - y2_output_loss: 8.4723 - y2_output_mae: 2.0774 - val_loss: 58.3481 - val_y1_output_loss: 33.8424 - val_y1_output_mae: 4.5431 - val_y2_output_loss: 25.5156 - val_y2_output_mae: 3.7457
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.9468 - y1_output_loss: 6.0833 - y1_output_mae: 1.7143 - y2_output_loss: 7.8369 - y2_output_mae: 2.0578 - val_loss: 66.9506 - val_y1_output_loss: 35.3337 - val_y1_output_mae: 4.6433 - val_y2_output_loss: 32.7273 - val_y2_output_mae: 4.2798
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.3414 - y1_output_loss: 6.0831 - y1_output_mae: 1.7675 - y2_output_loss: 7.2334 - y2_output_mae: 1.9194 - val_loss: 47.1393 - val_y1_output_loss: 28.7007 - val_y1_output_mae: 4.1787 - val_y2_output_loss: 19.2629 - val_y2_output_mae: 3.1915
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.9749 - y1_output_loss: 5.5071 - y1_output_mae: 1.6170 - y2_output_loss: 9.4473 - y2_output_mae: 2.1801 - val_loss: 55.1212 - val_y1_output_loss: 28.5688 - val_y1_output_mae: 4.1112 - val_y2_output_loss: 27.5386 - val_y2_output_mae: 3.9317
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.7749 - y1_output_loss: 5.8574 - y1_output_mae: 1.6603 - y2_output_loss: 7.8731 - y2_output_mae: 1.9779 - val_loss: 50.5445 - val_y1_output_loss: 30.7781 - val_y1_output_mae: 4.3577 - val_y2_output_loss: 20.6958 - val_y2_output_mae: 3.3083
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.3616 - y1_output_loss: 4.7057 - y1_output_mae: 1.5452 - y2_output_loss: 6.6828 - y2_output_mae: 1.8619 - val_loss: 57.1608 - val_y1_output_loss: 30.9489 - val_y1_output_mae: 4.3162 - val_y2_output_loss: 27.1905 - val_y2_output_mae: 3.8894
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.0887 - y1_output_loss: 5.6369 - y1_output_mae: 1.7043 - y2_output_loss: 8.4609 - y2_output_mae: 2.0401 - val_loss: 59.1156 - val_y1_output_loss: 32.7947 - val_y1_output_mae: 4.4715 - val_y2_output_loss: 27.3908 - val_y2_output_mae: 3.9285
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.5556 - y1_output_loss: 5.9280 - y1_output_mae: 1.6953 - y2_output_loss: 7.6060 - y2_output_mae: 1.9867 - val_loss: 62.8201 - val_y1_output_loss: 36.8028 - val_y1_output_mae: 4.7763 - val_y2_output_loss: 27.1869 - val_y2_output_mae: 3.8724
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.0862 - y1_output_loss: 5.6105 - y1_output_mae: 1.6648 - y2_output_loss: 8.4543 - y2_output_mae: 2.0309 - val_loss: 64.3910 - val_y1_output_loss: 36.0605 - val_y1_output_mae: 4.7919 - val_y2_output_loss: 29.4026 - val_y2_output_mae: 4.0980
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.0062 - y1_output_loss: 4.4773 - y1_output_mae: 1.5179 - y2_output_loss: 6.5452 - y2_output_mae: 1.8496 - val_loss: 52.6029 - val_y1_output_loss: 31.6943 - val_y1_output_mae: 4.4921 - val_y2_output_loss: 21.7453 - val_y2_output_mae: 3.4081
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.2596 - y1_output_loss: 5.7836 - y1_output_mae: 1.7030 - y2_output_loss: 7.4935 - y2_output_mae: 1.9637 - val_loss: 51.7160 - val_y1_output_loss: 30.1100 - val_y1_output_mae: 4.3335 - val_y2_output_loss: 22.4877 - val_y2_output_mae: 3.5301
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.8120 - y1_output_loss: 5.7045 - y1_output_mae: 1.7104 - y2_output_loss: 7.0922 - y2_output_mae: 1.9051 - val_loss: 52.1340 - val_y1_output_loss: 28.0808 - val_y1_output_mae: 4.1147 - val_y2_output_loss: 24.9666 - val_y2_output_mae: 3.6594
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.7463 - y1_output_loss: 5.2305 - y1_output_mae: 1.6042 - y2_output_loss: 7.5028 - y2_output_mae: 2.0210 - val_loss: 62.1053 - val_y1_output_loss: 34.2748 - val_y1_output_mae: 4.6115 - val_y2_output_loss: 28.8489 - val_y2_output_mae: 4.0198
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.6456 - y1_output_loss: 6.6724 - y1_output_mae: 1.6827 - y2_output_loss: 6.9375 - y2_output_mae: 1.8723 - val_loss: 62.3367 - val_y1_output_loss: 34.0752 - val_y1_output_mae: 4.5033 - val_y2_output_loss: 29.3168 - val_y2_output_mae: 4.0620
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.8858 - y1_output_loss: 5.5355 - y1_output_mae: 1.7006 - y2_output_loss: 8.3194 - y2_output_mae: 2.0346 - val_loss: 51.6276 - val_y1_output_loss: 32.9497 - val_y1_output_mae: 4.5298 - val_y2_output_loss: 19.6366 - val_y2_output_mae: 3.1822
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.8862 - y1_output_loss: 6.7030 - y1_output_mae: 1.8101 - y2_output_loss: 8.1845 - y2_output_mae: 2.0646 - val_loss: 59.1274 - val_y1_output_loss: 35.0167 - val_y1_output_mae: 4.6735 - val_y2_output_loss: 25.1411 - val_y2_output_mae: 3.7079
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.6758 - y1_output_loss: 4.8703 - y1_output_mae: 1.5684 - y2_output_loss: 6.7854 - y2_output_mae: 1.8113 - val_loss: 61.8210 - val_y1_output_loss: 32.6393 - val_y1_output_mae: 4.4659 - val_y2_output_loss: 30.2490 - val_y2_output_mae: 4.1215
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.3505 - y1_output_loss: 6.5620 - y1_output_mae: 1.7977 - y2_output_loss: 7.8176 - y2_output_mae: 1.9574 - val_loss: 52.3904 - val_y1_output_loss: 29.2929 - val_y1_output_mae: 4.2636 - val_y2_output_loss: 23.9720 - val_y2_output_mae: 3.5573
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13.1199 - y1_output_loss: 5.2887 - y1_output_mae: 1.6097 - y2_output_loss: 7.8678 - y2_output_mae: 2.0301 - val_loss: 58.3861 - val_y1_output_loss: 31.1741 - val_y1_output_mae: 4.4473 - val_y2_output_loss: 28.2798 - val_y2_output_mae: 3.9933

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Evaluamos el modelo
results = model.evaluate(X_test, [y1_test, y2_test], verbose=0)

test_loss, y1_loss, y2_loss, test_mae_heating, test_mae_cooling = results

print(f"Total Test Loss: {test_loss:.4f}")
print(f"Heating Loss: {y1_loss:.4f}, Cooling Loss: {y2_loss:.4f}")
print(f"Test MAE for Heating Load: {test_mae_heating:.4f} Wh")
print(f"Test MAE for Cooling Load: {test_mae_cooling:.4f} Wh")
# Out:
# Total Test Loss: 58.3861
# Heating Loss: 31.1741, Cooling Loss: 28.2798
# Test MAE for Heating Load: 4.4473 Wh
# Test MAE for Cooling Load: 3.9933 Wh

# %%
import matplotlib.pyplot as plt


print(history.history.keys())

# ---- Graficamos el loss, que en este caso decidimos que fuera el MSE
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Total Training Loss')
plt.plot(history.history['val_loss'], label='Total Validation Loss')
plt.plot(history.history['y1_output_loss'], label='Heating Training Loss')
plt.plot(history.history['val_y1_output_loss'], label='Heating Validation Loss')
plt.plot(history.history['y2_output_loss'], label='Cooling Training Loss')
plt.plot(history.history['val_y2_output_loss'], label='Cooling Validation Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# Graficamos el MAE
plt.figure(figsize=(10, 6))
plt.plot(history.history['y1_output_mae'], label='Heating Training MAE')
plt.plot(history.history['val_y1_output_mae'], label='Heating Validation MAE')
plt.plot(history.history['y2_output_mae'], label='Cooling Training MAE')
plt.plot(history.history['val_y2_output_mae'], label='Cooling Validation MAE')
plt.title('Model MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE (Wh)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# dict_keys(['loss', 'val_loss', 'val_y1_output_loss', 'val_y1_output_mae', 'val_y2_output_loss', 'val_y2_output_mae', 'y1_output_loss', 'y1_output_mae', 'y2_output_loss', 'y2_output_mae'])

# %%
# Realizar predicciones
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

#Como tenemos dos targets, las predicciones hay que separarlas
y_train_pred_heating = y_pred_train[0].flatten()
y_train_pred_cooling = y_pred_train[1].flatten()

y_test_pred_heating = y_pred_test[0].flatten()
y_test_pred_cooling = y_pred_test[1].flatten()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
#Metricas de performance para heating

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

def regression_metrics(y_true, y_pred):
    r2 = r2_score(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    rmse = np.sqrt(root_mean_squared_error(y_true, y_pred))
    return r2, mae, rmse

# Metricas train
r2_train_heat, mae_train_heat, rmse_train_heat = regression_metrics(y1_train, y_train_pred_heating)
r2_train_cool, mae_train_cool, rmse_train_cool = regression_metrics(y2_train, y_train_pred_cooling)
print("=== Train Performance ===")
print(f"Heating Load: R²={r2_train_heat:.3f}, MAE={mae_train_heat:.3f}, RMSE={rmse_train_heat:.3f}")
print(f"Cooling Load: R²={r2_train_cool:.3f}, MAE={mae_train_cool:.3f}, RMSE={rmse_train_cool:.3f}")

# metricas test
r2_test_heat, mae_test_heat, rmse_test_heat = regression_metrics(y1_test, y_test_pred_heating)
r2_test_cool, mae_test_cool, rmse_test_cool = regression_metrics(y2_test, y_test_pred_cooling)
print("\n=== Test Performance ===")
print(f"Heating Load: R²={r2_test_heat:.3f}, MAE={mae_test_heat:.3f}, RMSE={rmse_test_heat:.3f}")
print(f"Cooling Load: R²={r2_test_cool:.3f}, MAE={mae_test_cool:.3f}, RMSE={rmse_test_cool:.3f}")
# Out:
# === Train Performance ===
# Heating Load: R²=0.723, MAE=4.224, RMSE=2.298
# Cooling Load: R²=0.732, MAE=3.631, RMSE=2.213
#
# === Test Performance ===
# Heating Load: R²=0.705, MAE=4.447, RMSE=2.355
# Cooling Load: R²=0.702, MAE=3.993, RMSE=2.293

# %% [markdown]
# #### Cross Validation

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import layers, models

def build_model(input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # Capas compartidas
    x = layers.Dense(128, activation='relu')(input_layer)
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    
    # Heating
    h = layers.Dense(64, activation='relu')(x)
    h = layers.Dropout(0.2)(h)
    h = layers.Dense(32, activation='relu')(h)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling
    c = layers.Dense(64, activation='relu')(x)
    c = layers.Dropout(0.2)(c)
    c = layers.Dense(32, activation='relu')(c)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    model.compile(optimizer='adam', loss='mse')
    return model

# %%
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler
from numpy import sqrt

#KFold
kf = KFold(n_splits=5, shuffle=True, random_state=42)

r2_heat, r2_cool = [], []
mae_heat, mae_cool = [], []
rmse_heat, rmse_cool = [], []

for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f"\n Fold {fold+1}")
    
    # Split data
    X_train, X_val = X[train_idx], X[val_idx]
    y_train_heat, y_val_heat = df['Y1'][train_idx], df['Y1'][val_idx]
    y_train_cool, y_val_cool = df['Y2'][train_idx], df['Y2'][val_idx]
    
    # Scale inputs
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    
    # Build & train model
    model = build_model(X.shape[1])
    model.fit(
        X_train, [y_train_heat, y_train_cool],
        epochs=80, batch_size=32, verbose=0
    )
    
    # Predict
    y_pred_heat, y_pred_cool = model.predict(X_val, verbose=0)
    
    # Flatten
    y_pred_heat, y_pred_cool = y_pred_heat.flatten(), y_pred_cool.flatten()
    
    # Compute metrics
    r2_heat.append(r2_score(y_val_heat, y_pred_heat))
    r2_cool.append(r2_score(y_val_cool, y_pred_cool))
    mae_heat.append(mean_absolute_error(y_val_heat, y_pred_heat))
    mae_cool.append(mean_absolute_error(y_val_cool, y_pred_cool))
    rmse_heat.append(sqrt(mean_squared_error(y_val_heat, y_pred_heat)))
    rmse_cool.append(sqrt(mean_squared_error(y_val_cool, y_pred_cool)))
# Out:
#  Fold 1
#
#  Fold 2
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x36d6c4b80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 3
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x36cf884a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
#  Fold 4
#
#  Fold 5

# %%
print("\n=== Cross-Validation Results ===")
print(f"Heating Load: R2={np.mean(r2_heat):.3f}±{np.std(r2_heat):.3f}, "
      f"MAE={np.mean(mae_heat):.3f}, RMSE={np.mean(rmse_heat):.3f}")
print(f"Cooling Load: R2={np.mean(r2_cool):.3f}±{np.std(r2_cool):.3f}, "
      f"MAE={np.mean(mae_cool):.3f}, RMSE={np.mean(rmse_cool):.3f}")
# Out:
# === Cross-Validation Results ===
# Heating Load: R2=0.959±0.010, MAE=1.498, RMSE=2.016
# Cooling Load: R2=0.930±0.010, MAE=1.785, RMSE=2.504

# %% [markdown]
# ## Tuneo de hiperparametros
#
# Especificamente diseniado para redes neuronales

# %%
# Random Serach
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models, optimizers

df = pd.read_csv("ENB2012_data.csv")
X_full = df[['X1','X2','X3','X4','X5','X6','X7','X8']].values
y1_full = df['Y1'].values
y2_full = df['Y2'].values

scaler = StandardScaler()
X_full = scaler.fit_transform(X_full)


X_train_full, X_test_full, y1_train_full, y1_test_full, y2_train_full, y2_test_full = train_test_split(
    X_full, y1_full, y2_full, test_size=0.2, random_state=42
)


# Definimos el contructor del modelo

def build_random_model(params, input_dim):
    input_layer = layers.Input(shape=(input_dim,))
    
    # compartidas
    x = input_layer
    for i in range(params['n_shared_layers']):
        x = layers.Dense(params['n_shared_units'], activation='relu')(x)
        x = layers.Dropout(params['dropout_rate'])(x)
    
    # Heating 
    h = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y1 = layers.Dense(1, name='heating_output')(h)
    
    # Cooling 
    c = layers.Dense(params['n_shared_units']//2, activation='relu')(x)
    y2 = layers.Dense(1, name='cooling_output')(c)
    
    model = models.Model(inputs=input_layer, outputs=[y1, y2])
    
    opt = optimizers.Adam(learning_rate=params['learning_rate'])
    model.compile(
        optimizer=opt,
        loss={'heating_output': 'mse', 'cooling_output': 'mse'},
        metrics={'heating_output': 'mae', 'cooling_output': 'mae'}
    )
    
    return model


# Espacio para el random search

param_distributions = {
    'n_shared_layers': [1, 2, 3],
    'n_shared_units': [32, 64, 128, 256],
    'dropout_rate': [0.0, 0.1, 0.2, 0.3, 0.4],
    'learning_rate': [1e-4, 5e-4, 1e-3, 5e-3],
    'batch_size': [16, 32, 64]
}


n_trials = 5
results = []

print("\n Empezamos Random Search")
for i in range(n_trials):
    params = {k: random.choice(v) for k, v in param_distributions.items()}
    print(f"\nTrial {i+1}/{n_trials} with params: {params}")
    
    X_train_rs, X_val_rs, y1_train_rs, y1_val_rs, y2_train_rs, y2_val_rs = train_test_split(
        X_train_full, y1_train_full, y2_train_full, test_size=0.2, random_state=i
    )
    
    model = build_random_model(params, X_train_rs.shape[1])
    history = model.fit(
        X_train_rs, [y1_train_rs, y2_train_rs],
        validation_data=(X_val_rs, [y1_val_rs, y2_val_rs]),
        epochs=50, batch_size=params['batch_size'], verbose=0
    )
    
    val_loss = np.mean(history.history['val_loss'][-5:])
    results.append((params, val_loss))
    print(f"Validation Loss: {val_loss:.4f}")

# Resultados
results.sort(key=lambda x: x[1])
print("\n Results")
for rank, (params, loss) in enumerate(results, 1):
    print(f"{rank:2d}) Val Loss={loss:.4f} | Params={params}")

best_params, best_loss = results[0]
print("\n Mejor configuracion:")
print(best_params)
print(f"Validation Loss: {best_loss:.4f}")
# Out:
#  Empezamos Random Search
#
# Trial 1/5 with params: {'n_shared_layers': 3, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.001, 'batch_size': 64}
# Validation Loss: 23.5665
#
# Trial 2/5 with params: {'n_shared_layers': 1, 'n_shared_units': 128, 'dropout_rate': 0.4, 'learning_rate': 0.0005, 'batch_size': 16}
# Validation Loss: 19.9570
#
# Trial 3/5 with params: {'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.2, 'learning_rate': 0.005, 'batch_size': 64}
# Validation Loss: 12.6823
#
# Trial 4/5 with params: {'n_shared_layers': 3, 'n_shared_units': 32, 'dropout_rate': 0.4, 'learning_rate': 0.005, 'batch_size': 16}
# Validation Loss: 21.7358
#
# Trial 5/5 with params: {'n_shared_layers': 1, 'n_shared_units': 64, 'dropout_rate': 0.4, 'learning_rate': 0.001, 'batch_size': 32}
# Validation Loss: 24.3511
#
#  Results
#  1) Val Loss=12.6823 | Params={'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.2, 'learning_rate': 0.005, 'batch_size': 64}
#  2) Val Loss=19.9570 | Params={'n_shared_layers': 1, 'n_shared_units': 128, 'dropout_rate': 0.4, 'learning_rate': 0.0005, 'batch_size': 16}
#  3) Val Loss=21.7358 | Params={'n_shared_layers': 3, 'n_shared_units': 32, 'dropout_rate': 0.4, 'learning_rate': 0.005, 'batch_size': 16}
#  4) Val Loss=23.5665 | Params={'n_shared_layers': 3, 'n_shared_units': 32, 'dropout_rate': 0.0, 'learning_rate': 0.001, 'batch_size': 64}
#  5) Val Loss=24.3511 | Params={'n_shared_layers': 1, 'n_shared_units': 64, 'dropout_rate': 0.4, 'learning_rate': 0.001, 'batch_size': 32}
#
#  Mejor configuracion:
# {'n_shared_layers': 3, 'n_shared_units': 128, 'dropout_rate': 0.2, 'learning_rate': 0.005, 'batch_size': 64}
# Validation Loss: 12.6823

# %% [markdown]
# #### Algunas referencias
#
# - https://keras.io/guides/sequential_model/
# - https://keras.io/api/layers/activations/
# - https://keras.io/optimizers/
# - https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=spiral&regDataset=reg-gauss&learningRate=0.03&regularizationRate=0.003&noise=20&networkShape=4&seed=0.82538&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=regression&initZero=false&hideText=false
